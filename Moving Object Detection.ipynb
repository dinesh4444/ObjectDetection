# %%
import cv2
import time 
import imutils

# %%
cam = cv2.VideoCapture(0)
time.sleep(1)
fristFrame = None
area = 500

while True:
    _,img = cam.read()
    text = "Normal"
    img = imutils.resize(img, width=500)
    grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gaussianImg = cv2.GaussianBlur(grayImg, (21,21), 0)
    if fristFrame is None:
        fristFrame = gaussianImg
        continue
    
    imgDiff = cv2.absdiff(fristFrame, gaussianImg)
    threshImg = cv2.threshold(imgDiff, 25, 255, cv2.THRESH_BINARY)[1]
    threshImg = cv2.dilate(threshImg, None, iterations=2)
    cnts = cv2.findContours(threshImg.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    
    for c in cnts:
        if cv2.contourArea(c) < area:
            continue
        (x, y, w, h) = cv2.boundingRect(c)
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
        text = "Moving Object Detected"
        print(text)
        
    cv2.putText(img, text, (10,20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2 )
    cv2.imshow('CameraFeed', img)
    
    key = cv2.waitKey(1) & 0xFF
    if key == ord("q"):
        break
        
cam.release()
cv2.destroyAllWindows()
# Out:
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# Moving Object Detected
# ...

# %%
import cv2
import imutils
import time
from datetime import datetime

cam = cv2.VideoCapture(0)
time.sleep(1)

fristFrame = None
area = 500
count = 0

while True:
    _,img = cam.read()
    text = "Normal"
    img = imutils.resize(img, width=500)
    grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gaussianImg = cv2.GaussianBlur(grayImg, (21,21), 0)
    if fristFrame is None:
        fristFrame = gaussianImg
        continue
        
    imgDiff = cv2.absdiff(fristFrame, gaussianImg)
    threshImg = cv2.threshold(grayImg, 25, 255, cv2.THRESH_BINARY)[1]
    threshImg = cv2.dilate(threshImg, None, iterations=2)
    cnts = cv2.findContours(threshImg.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    for c in cnts:
        if cv2.contourArea(c) < area:
            continue
        (x,y,w,h) = cv2.boundingRect(c)
        cv2.rectangle(img, (x,y),(x+w, y+h), (0,255,0), 2)
        text = "Moving Object Detected"
        count += 1
        dt_string = (datetime.now().strftime("%d/%M/%y%H%M%S"))
        print(text,count)   #by placing "@", dt_string inside parenthesis we can print date in shell window
        num = str(count)
        cv2.putText(img, text, (10,20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)
        cv2.putText(img, "Count", (230,20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255),2)
        cv2.putText(img, text, (10,20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)
        cv2.imshow('VideoStreaming', img)
        
        key = cv2.waitKey(1) & 0xFF
        if key == ord("q"):
            break
            
cam.release()
cv2.destroyAllWindows()
# Out:
# Moving Object Detected 1
# Moving Object Detected 2
# Moving Object Detected 3
# Moving Object Detected 4
# Moving Object Detected 5
# Moving Object Detected 6
# Moving Object Detected 7
# Moving Object Detected 8
# Moving Object Detected 9
# Moving Object Detected 10
# Moving Object Detected 11
# Moving Object Detected 12
# Moving Object Detected 13
# Moving Object Detected 14
# Moving Object Detected 15
# Moving Object Detected 16
# Moving Object Detected 17
# Moving Object Detected 18
# Moving Object Detected 19
# Moving Object Detected 20
# Moving Object Detected 21
# Moving Object Detected 22
# Moving Object Detected 23
# Moving Object Detected 24
# Moving Object Detected 25
# Moving Object Detected 26
# Moving Object Detected 27
# Moving Object Detected 28
# Moving Object Detected 29
# Moving Object Detected 30
# Moving Object Detected 31
# Moving Object Detected 32
# Moving Object Detected 33
# Moving Object Detected 34
# Moving Object Detected 35
# Moving Object Detected 36
# ...
